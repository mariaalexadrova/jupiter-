# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv', index_col = 'PassengerId')

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
#Какое количество мужчин и женщин ехало на корабле? В качестве
#ответа приведите два числа через пробел.
sex = data.groupby('Sex').agg({'Sex':'count'})
sex = sex['Sex'].tolist()
print(*sex)
# Out:
# 314 577

# %%
#Какой части пассажиров удалось выжить? Посчитайте долю выживших пассажиров. Ответ приведите в процентах
survived = data.Survived.sum()
aLL = data.Sex.count()
print(round(survived*100/aLL, 2))
# Out:
# 38.38

# %%
#Какую долю пассажиры первого класса составляли среди всех пассажиров? Ответ приведите в процентах
pclass = data.groupby('Pclass').agg({'Pclass':'count'})
cAll = pclass.Pclass.tolist()
c1 = cAll[0]
print(round(c1*100/aLL, 2))
# Out:
# 24.24

# %%
#1)# Какого возраста были пассажиры? Посчитайте среднее и медиану возраста пассажиров. Посчитайте среднее и медиану возраста
#пассажиров. В качестве ответа приведите два числа через пробел.
medi = data.Age.median()
sra = data.Age.fillna(medi).mean()
print(sra, medi)
# Out:
# 29.36158249158249 28.0

# %%
#2)#
data = data.dropna()
medi = data.Age.median()
sra = data.Age.mean()
print(sra, medi)
# Out:
# 35.6744262295082 36.0

# %%
#Коррелируют ли число братьев/сестер с числом родителей/детей?
#Посчитайте корреляцию Пирсона между признаками SibSp и Parch.
data[['SibSp','Parch']].corr()
# Out:
#           SibSp     Parch
# SibSp  1.000000  0.255346
# Parch  0.255346  1.000000

# %%
data[['SibSp','Parch']].corr()
# Out:
#           SibSp     Parch
# SibSp  1.000000  0.414838
# Parch  0.414838  1.000000

# %%
#Какое самое популярное женское имя на корабле? Извлеките из
#полного имени пассажира (колонка Name) его личное имя (First
#Name). Это задание — типичный пример того, с чем сталкивается специалист по анализу данных
#Vestrom, Miss. Hulda Amanda Adolfina
def col(S):
    if S.find('Mr.') >= 0:
        return
    elif S.find('Miss. ') >= 0:
        ss = S.find('Miss. ')
        S = S[ss+6:]
        cc = S.find(' ')
        
        return S[:cc]
        
    else:
        rs = S.find('(')


        S = S[rs+1:]
        sr = S.find(' ')
        d = S[:sr]
        if d[-1] == ',':
            return d[:-1]
        else:
        
            return d

# %%
data.Name = data.Name.apply(col)

# %%
data.Name = data.Name.dropna()

# %%
data.Name.value_counts()
# Out:
# Anna         12
# Margaret     10
# Elizabeth     9
# Mary          8
# Mar           6
#              ..
# Lucille       1
# Elle          1
# Telma         1
# Susan         1
# Eugeni        1
# Name: Name, Length: 247, dtype: int64
